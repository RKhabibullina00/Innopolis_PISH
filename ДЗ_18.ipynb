# %% [markdown]
# <a href="https://colab.research.google.com/github/enikeevaRAMZ/Innopolis_PISH/blob/main/%D0%94%D0%97_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("US-News-Rankings-Liberal-Arts-Colleges-Through-2023.csv")

# %%
df
# Out:
#                        College Name State  IPEDS ID 2023          2022  \
# 0                  Williams College    MA    168342    1             1
# 1                   Amherst College    MA    164465    2             2
# 2                    Pomona College    CA    121345    3             4
# 3                Swarthmore College    PA    216287    4             3
# 4                 Wellesley College    MA    168218    5             5
# ..                              ...   ...       ...  ...           ...
# 356        William Peace University    NC    199272  NaN           NaN
# 357     Williams Baptist University    AR    107877  NaN  T2 (168-222)
# 358              Wingate University    NC    199962  NaN           NaN
# 359      Wisconsin Lutheran College    WI    240338  NaN           NaN
# 360  Xavier University of Louisiana    LA    160904  NaN           NaN
#
#              2021          2020          2019 2018 2017  ...  1995  1994 1993  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 361 entries, 0 to 360
# Data columns (total 41 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   College Name  361 non-null    object
#  1   State         361 non-null    object
#  2   IPEDS ID      361 non-null    int64
#  3   2023          200 non-null    object
#  4   2022          222 non-null    object
#  5   2021          221 non-null    object
#  6   2020          215 non-null    object
#  7   2019          229 non-null    object
#  8   2018          172 non-null    object
#  9   2017          178 non-null    object
#  10  2016          176 non-null    float64
#  11  2015          181 non-null    float64
#  12  2014          182 non-null    object
#  13  2013          180 non-null    object
#  14  2012          182 non-null    object
#  15  2011          188 non-null    float64
#  16  2010          126 non-null    float64
#  17  2009          124 non-null    float64
# ...

# %%
df.isnull()
# Out:
#      College Name  State  IPEDS ID   2023   2022   2021   2020   2019   2018  \
# 0           False  False     False  False  False  False  False  False  False
# 1           False  False     False  False  False  False  False  False  False
# 2           False  False     False  False  False  False  False  False  False
# 3           False  False     False  False  False  False  False  False  False
# 4           False  False     False  False  False  False  False  False  False
# ..            ...    ...       ...    ...    ...    ...    ...    ...    ...
# 356         False  False     False   True   True   True   True  False   True
# 357         False  False     False   True  False  False  False   True   True
# 358         False  False     False   True   True   True   True   True   True
# 359         False  False     False   True   True   True   True   True   True
# 360         False  False     False   True   True   True   True   True   True
#
# ...

# %%
df.loc[df.isnull().any(axis=1)]
# Out:
#                        College Name State  IPEDS ID 2023          2022  \
# 5                   Bowdoin College    ME    161004    6             6
# 7       United States Naval Academy    MD    164155    6             6
# 8         Claremont McKenna College    CA    112260    9             8
# 9    United States Military Academy    NY    197036    9            11
# 10               Middlebury College    VT    230959   11             9
# ..                              ...   ...       ...  ...           ...
# 356        William Peace University    NC    199272  NaN           NaN
# 357     Williams Baptist University    AR    107877  NaN  T2 (168-222)
# 358              Wingate University    NC    199962  NaN           NaN
# 359      Wisconsin Lutheran College    WI    240338  NaN           NaN
# 360  Xavier University of Louisiana    LA    160904  NaN           NaN
#
#              2021          2020          2019 2018 2017  ...  1995  1994 1993  \
# ...

# %%
df.corr()
# Out:
# <ipython-input-22-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#           IPEDS ID      2016      2015      2011      2010      2009  \
# IPEDS ID  1.000000  0.065700  0.046088  0.084075  0.095762  0.055665
# 2016      0.065700  1.000000  0.990136  0.947642  0.945973  0.939782
# 2015      0.046088  0.990136  1.000000  0.959750  0.941297  0.939045
# 2011      0.084075  0.947642  0.959750  1.000000  0.971979  0.970787
# 2010      0.095762  0.945973  0.941297  0.971979  1.000000  0.989589
# 2009      0.055665  0.939782  0.939045  0.970787  0.989589  1.000000
# 2002      0.228636  0.925360  0.919697  0.945061  0.952807  0.957397
# 1990     -0.039120  0.522872  0.459238  0.540212  0.603770  0.637049
# 1989      0.090557  0.575054  0.516817  0.632201  0.655360  0.717561
# ...

# %%
df['IPEDS ID'].sum()
# Out:
# 67951963

# %%
df.mean()
# Out:
# <ipython-input-41-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# IPEDS ID    188232.584488
# 2016            86.829545
# 2015            89.342541
# 2011            92.824468
# 2010            61.896825
# 2009            61.169355
# 2002            25.215686
# 1990            12.880000
# 1989            13.000000
# 1988            13.307692
# 1986             7.071429
# 1984             5.916667
# dtype: float64

# %%
df['1984'].median()
# Out:
# 6.5

# %%
df['1984'].std()
# Out:
# 3.058767824804721

# %%
df[df['1990']>=20]
# Out:
#                  College Name State  IPEDS ID 2023 2022 2021 2020 2019 2018  \
# 8   Claremont McKenna College    CA    112260    9    8    6    7    9    8
# 16           Hamilton College    NY    191515   15   13    9   14   16   18
# 17            Barnard College    NY    189097   18   17   22   25   25   26
# 23              Colby College    ME    161086   24   17   15   11   18   12
# 24              Bates College    ME    160977   25   25   22   21   22   23
# 43            Trinity College    CT    130590   39   46   44   46   46   44
#
#    2017  ...        1995        1994        1993        1992        1991  \
# 8     9  ...          12          11          16          14          13
# 16   12  ...  T1 (26-40)          22          21          25          19
# 17   27  ...  T1 (26-40)  Q1 (26-35)  Q1 (26-35)          19          25
# 23   12  ...          23          17          15          20          18
# ...
